// %%
var crownN = (queens, i) => {
  var n = i+1;
  return `
.crown-${n} {
  left: ${1.0 / (queens[i] % 8)*100}%;
  top: ${Math.ceil(queens[i] / 8)*100}%;
}`
}

var visualize = (queens) => 
  $$.html(`
<style>
.all {
  position: static;
  width: 400px;
  height: 400px;
}

.board {
  position: absolute;
  left: 0;
  top: 0;
  width: 100%;
  height: 100%;
}

.crown {
  position: relative;
  width: 12%;
  height: 12%;
}

${crownN(queens, 0)}
${crownN(queens, 1)}
${crownN(queens, 2)}
${crownN(queens, 3)}
${crownN(queens, 4)}
${crownN(queens, 5)}
${crownN(queens, 6)}
${crownN(queens, 7)}

</style>

<div class="all">
<img class="board" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Board.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-1" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown1.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-2" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown2.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-3" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown3.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-4" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown4.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-5" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown5.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-6" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown6.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-7" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown7.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
<img class="crown crown-8" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Crown8.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
</div>
`);

visualize([ 10, 25, 5, 22, 48, 59, 39, 44 ])
// Out:
// <style>
// .all {
//   position: relative;
//   width: 400px;
//   height: 400px;
// }
//
// .board {
//   position: relative;
//   left: 0;
//   top: 0;
//   width: 100%;
//   height: 100%;
// }
//
// .crown {
//   position: relative;
//   width: 12%;
//   height: 12%;
// }
//
//
// .crown-1 {
//   left: 50%;
//   top: 200%;
// }
//
// .crown-2 {
//   left: 100%;
//   top: 400%;
// }
//
// .crown-3 {
//   left: 20%;
//   top: 100%;
// }
//
// .crown-4 {
//   left: 16.666666666666664%;
//   top: 300%;
// }
//
// .crown-5 {
//   left: Infinity%;
//   top: 600%;
// }
//
// .crown-6 {
//   left: 33.33333333333333%;
//   top: 800%;
// }
//
// .crown-7 {
//   left: 14.285714285714285%;
//   top: 500%;
// }
//
// .crown-8 {
//   left: 25%;
//   top: 600%;
// }
//
// </style>
//
// <div class="all">
// <img class="board" src="https://jupyter.social-cartography.net/user/thwee/files/Eight%20Queens/notebook/Board.png?_xsrf=2%7C2e1efd5e%7C89a3464cc277c0842b98641104b6d55c%7C1583086869"></img>
// ...
